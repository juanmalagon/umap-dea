# %% [markdown]
# # Compare Four Runs

# %%
# ═══════════════════════════════════════════════════════════
# 1. Load data
# ═══════════════════════════════════════════════════════════
from compare_four_runs_data import load_data

df = load_data()

# %%
# ═══════════════════════════════════════════════════════════
# 2. Load config (edit compare_four_runs_config.json)
# ═══════════════════════════════════════════════════════════
from compare_four_runs_config import load_config

cfg = load_config()

# Unpack Run A
ra = cfg["run_a"]
RUN_A_ALGO = ra["algo"]
RUN_A_N = ra["N"]
RUN_A_n = ra["n"]
RUN_A_RTS = ra["rts"]
RUN_A_GAMMA = ra["gamma"]
RUN_A_UMAP_N_NEIGHBORS = ra["umap_n_neighbors"]
RUN_A_NR_SIMULATIONS = ra["nr_simulations"]

# Unpack Run B
rb = cfg["run_b"]
RUN_B_ALGO = rb["algo"]
RUN_B_N = rb["N"]
RUN_B_n = rb["n"]
RUN_B_RTS = rb["rts"]
RUN_B_GAMMA = rb["gamma"]
RUN_B_UMAP_N_NEIGHBORS = rb["umap_n_neighbors"]
RUN_B_NR_SIMULATIONS = rb["nr_simulations"]

# Unpack Run C
rc = cfg["run_c"]
RUN_C_ALGO = rc["algo"]
RUN_C_N = rc["N"]
RUN_C_n = rc["n"]
RUN_C_RTS = rc["rts"]
RUN_C_GAMMA = rc["gamma"]
RUN_C_UMAP_N_NEIGHBORS = rc["umap_n_neighbors"]
RUN_C_NR_SIMULATIONS = rc["nr_simulations"]

# Unpack Run D
rd = cfg["run_d"]
RUN_D_ALGO = rd["algo"]
RUN_D_N = rd["N"]
RUN_D_n = rd["n"]
RUN_D_RTS = rd["rts"]
RUN_D_GAMMA = rd["gamma"]
RUN_D_UMAP_N_NEIGHBORS = rd["umap_n_neighbors"]
RUN_D_NR_SIMULATIONS = rd["nr_simulations"]

# Shared
METRIC_NAME = cfg["metric_name"]
SHOW_STD = cfg["show_std"]

# %%
# ═══════════════════════════════════════════════════════════
# 3. Plot comparison (just run this cell after setting parameters)
# ═══════════════════════════════════════════════════════════
from compare_four_runs_plot import plot_comparison

plot_comparison(
    df,
    RUN_A_ALGO, RUN_A_N, RUN_A_n, RUN_A_RTS, RUN_A_GAMMA,
    RUN_A_UMAP_N_NEIGHBORS, RUN_A_NR_SIMULATIONS,
    RUN_B_ALGO, RUN_B_N, RUN_B_n, RUN_B_RTS, RUN_B_GAMMA,
    RUN_B_UMAP_N_NEIGHBORS, RUN_B_NR_SIMULATIONS,
    RUN_C_ALGO, RUN_C_N, RUN_C_n, RUN_C_RTS, RUN_C_GAMMA,
    RUN_C_UMAP_N_NEIGHBORS, RUN_C_NR_SIMULATIONS,
    RUN_D_ALGO, RUN_D_N, RUN_D_n, RUN_D_RTS, RUN_D_GAMMA,
    RUN_D_UMAP_N_NEIGHBORS, RUN_D_NR_SIMULATIONS,
    metric_name=METRIC_NAME,
    show_std=SHOW_STD,
)
